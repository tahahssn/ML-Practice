# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings("ignore")

df = pd.read_csv( 'PSL.csv')

df.head()
# Out:
#    id  match_id        date  season                                venue  \
# 0   1   1075986  2017-02-09    2017  Dubai International Cricket Stadium
# 1   2   1075986  2017-02-09    2017  Dubai International Cricket Stadium
# 2   3   1075986  2017-02-09    2017  Dubai International Cricket Stadium
# 3   4   1075986  2017-02-09    2017  Dubai International Cricket Stadium
# 4   5   1075986  2017-02-09    2017  Dubai International Cricket Stadium
#
#    inning    batting_team      bowling_team  over  ball  ... is_wicket  \
# 0       1  Peshawar Zalmi  Islamabad United     1     1  ...      True
# 1       1  Peshawar Zalmi  Islamabad United     1     2  ...     False
# 2       1  Peshawar Zalmi  Islamabad United     1     3  ...     False
# 3       1  Peshawar Zalmi  Islamabad United     1     4  ...     False
# 4       1  Peshawar Zalmi  Islamabad United     1     5  ...     False
#
#   player_dismissed dismissal_kind        fielder            winner     win_by  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73784 entries, 0 to 73783
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                73784 non-null  int64
#  1   match_id          73784 non-null  int64
#  2   date              73784 non-null  object
#  3   season            73784 non-null  int64
#  4   venue             73784 non-null  object
#  5   inning            73784 non-null  int64
#  6   batting_team      73784 non-null  object
#  7   bowling_team      73784 non-null  object
#  8   over              73784 non-null  int64
#  9   ball              73784 non-null  int64
#  10  batter            73784 non-null  object
#  11  bowler            73784 non-null  object
#  12  non_striker       73784 non-null  object
#  13  batsman_runs      73784 non-null  int64
#  14  extra_runs        73784 non-null  int64
#  15  total_runs        73784 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id      match_id        season        inning          over  \
# count  73784.000000  7.378400e+04  73784.000000  73784.000000  73784.000000
# mean     276.413952  1.247840e+06   2020.776578      1.481622     10.113182
# std      114.270171  1.430635e+05      2.759063      0.502263      5.644703
# min        1.000000  9.591750e+05   2016.000000      1.000000      1.000000
# 25%      193.000000  1.128851e+06   2018.000000      1.000000      5.000000
# 50%      277.000000  1.247024e+06   2021.000000      1.000000     10.000000
# 75%      360.000000  1.354945e+06   2023.000000      2.000000     15.000000
# max      555.000000  1.475271e+06   2025.000000      4.000000     20.000000
#
#                ball  batsman_runs    extra_runs    total_runs
# count  73784.000000  73784.000000  73784.000000  73784.000000
# mean       3.618901      1.290700      0.070205      1.360905
# std        1.812546      1.667167      0.359813      1.654922
# ...

# %%
print(f"your rows are {df.shape[0]} and your columns are {df.shape[1]}")
# Out:
# your rows are 73784 and your columns are 27

# %%
df.isnull().sum()
# Out:
# id                      0
# match_id                0
# date                    0
# season                  0
# venue                   0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batter                  0
# bowler                  0
# non_striker             0
# batsman_runs            0
# extra_runs              0
# total_runs              0
# extras_type         69772
# is_wicket               0
# player_dismissed    69818
# dismissal_kind      69818
# fielder             71148
# winner                  0
# win_by                  0
# match_type              0
# player_of_match       736
# umpire_1                0
# umpire_2                0
# dtype: int64

# %% [markdown]
# ##### Which team won the most matches?

# %%
winners = df['winner'].value_counts()
winners
# Out:
# winner
# Islamabad United     14510
# Peshawar Zalmi       13521
# Quetta Gladiators    12378
# Lahore Qalandars     11473
# Multan Sultans       10704
# Karachi Kings         9892
# No result             1306
# Name: count, dtype: int64

# %%
sns.barplot(x = winners.values , y = winners.index, palette = 'viridis')
plt.title('Most Matches Win By Teams')
# Out:
# Text(0.5, 1.0, 'Most Matches Win By Teams')

# %% [markdown]
# #### 1 Most "Player of the Match" Awards

# %%
count = df['player_of_match'].value_counts().head(10)
count
# Out:
# player_of_match
# Fakhar Zaman           2677
# RR Rossouw             1938
# Babar Azam             1886
# Faheem Ashraf          1689
# Kamran Akmal           1644
# L Ronchi               1582
# Mohammad Rizwan        1457
# Shaheen Shah Afridi    1443
# SR Watson              1424
# Shadab Khan            1393
# Name: count, dtype: int64

# %%
sns.barplot(x = count.values , y = count.index, palette = 'viridis')
plt.title("Top 10 plauers with man of the match")
# Out:
# Text(0.5, 1.0, 'Top 10 plauers with man of the match')

# %%
sns.barplot(x = venues.values, y = venues.index, palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73784 entries, 0 to 73783
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                73784 non-null  int64
#  1   match_id          73784 non-null  int64
#  2   date              73784 non-null  object
#  3   season            73784 non-null  int64
#  4   venue             73784 non-null  object
#  5   inning            73784 non-null  int64
#  6   batting_team      73784 non-null  object
#  7   bowling_team      73784 non-null  object
#  8   over              73784 non-null  int64
#  9   ball              73784 non-null  int64
#  10  batter            73784 non-null  object
#  11  bowler            73784 non-null  object
#  12  non_striker       73784 non-null  object
#  13  batsman_runs      73784 non-null  int64
#  14  extra_runs        73784 non-null  int64
#  15  total_runs        73784 non-null  int64
# ...

# %%
sns.countplot(y = df['win_by'])
plt.title("Won by")
# Out:
# Text(0.5, 1.0, 'Won by')

# %%
count = df['player_of_match'].value_counts().head(10)
count
# Out:
# player_of_match
# Fakhar Zaman           2677
# RR Rossouw             1938
# Babar Azam             1886
# Faheem Ashraf          1689
# Kamran Akmal           1644
# L Ronchi               1582
# Mohammad Rizwan        1457
# Shaheen Shah Afridi    1443
# SR Watson              1424
# Shadab Khan            1393
# Name: count, dtype: int64

# %%
sns.barplot(x = count.values , y = count.index, palette='mako')
plt.title("Top 10 plauers with man of the match")
# Out:
# Text(0.5, 1.0, 'Top 10 plauers with man of the match')

# %%
venues = df['venue'].value_counts()

# %%
sns.barplot(x = venues.values, y= venues.index, palette = 'viridis')
# Out:
# <Axes: ylabel='venue'>
