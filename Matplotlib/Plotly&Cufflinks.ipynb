# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tahas\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tahas\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\tahas\anaconda3\lib\site-packages (from plotly) (25.0)

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\tahas\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (2.3.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (2.3.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (6.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (80.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (9.7.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\tahas\anaconda3\lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\tahas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\tahas\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tahas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\tahas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\tahas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tahas\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tahas\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tahas\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tahas\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tahas\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.7.0)
# Requirement already satisfied: packaging in c:\users\tahas\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (25.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tahas\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tahas\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\tahas\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Ensure the data types are correct
tips['total_bill'] = tips['total_bill'].astype(float)
tips['day'] = tips['day'].astype(str)

# Now try the plot
tips[['total_bill', 'day']].iplot(
    kind='box',
    x='day',
    y='total_bill'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 6
#       3 tips['day'] = tips['day'].astype(str)
#       5 # Now try the plot
# ----> 6 tips[['total_bill', 'day']].iplot(
#       7     kind='box',
#       8     x='day',
#       9     y='total_bill'
#      10 )
#
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:911, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     909 for _ in columns:
#     910 	if kind=='box':
# --> 911 		__=Box(y=df[_].values.tolist(),marker=dict(color=clrs[_]),name=_,
#     912 				line=dict(width=width),boxpoints=boxpoints)
#     913 		# 114 - Horizontal Box
#     914 		__['orientation']=orientation
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objs\_box.py:2989, in Box.__init__(self, arg, alignmentgroup, boxmean, boxpoints, customdata, customdatasrc, dx, dy, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, jitter, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, lowerfence, lowerfencesrc, marker, mean, meansrc, median, mediansrc, meta, metasrc, name, notched, notchspan, notchspansrc, notchwidth, offsetgroup, opacity, orientation, pointpos, q1, q1src, q3, q3src, quartilemethod, sd, sdmultiple, sdsrc, selected, selectedpoints, showlegend, showwhiskers, sizemode, stream, text, textsrc, uid, uirevision, unselected, upperfence, upperfencesrc, visible, whiskerwidth, width, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2987 self._set_property("lowerfence", arg, lowerfence)
#    2988 self._set_property("lowerfencesrc", arg, lowerfencesrc)
# -> 2989 self._set_property("marker", arg, marker)
#    2990 self._set_property("mean", arg, mean)
#    2991 self._set_property("meansrc", arg, meansrc)
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objs\box\_marker.py:350, in Marker.__init__(self, arg, angle, color, line, opacity, outliercolor, size, symbol, **kwargs)
#     347 self._validate = kwargs.pop("_validate", True)
#     349 self._set_property("angle", arg, angle)
# --> 350 self._set_property("color", arg, color)
#     351 self._set_property("line", arg, line)
#     352 self._set_property("opacity", arg, opacity)
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of box.marker
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
